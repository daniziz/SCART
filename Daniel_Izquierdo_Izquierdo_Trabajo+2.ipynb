# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Obtención-de-los-datos-y-pre-processing" data-toc-modified-id="Obtención-de-los-datos-y-pre-processing-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Obtención de los datos y pre-processing</a></span></li><li><span><a href="#Consideraciones-iniciales" data-toc-modified-id="Consideraciones-iniciales-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Consideraciones iniciales</a></span><ul class="toc-item"><li><span><a href="#Train-validation-test-split" data-toc-modified-id="Train-validation-test-split-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Train-validation-test split</a></span><ul class="toc-item"><li><span><a href="#*Requisito:-En-todos-los-entrenamientos-de-esta-práctica,-se-requiere-utilizar-el-20%-de-los-datos-en-x_train-como--conjunto-de-datos-de-validación-*" data-toc-modified-id="*Requisito:-En-todos-los-entrenamientos-de-esta-práctica,-se-requiere-utilizar-el-20%-de-los-datos-en-x_train-como--conjunto-de-datos-de-validación-*-2.1.1"><span class="toc-item-num">2.1.1&nbsp;&nbsp;</span>*<em>Requisito: En todos los entrenamientos de esta práctica, se requiere utilizar el 20% de los datos en x_train como  conjunto de datos de validación *</em></a></span></li></ul></li><li><span><a href="#Un-error-común-con-modelos-de-Keras" data-toc-modified-id="Un-error-común-con-modelos-de-Keras-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Un error común con modelos de Keras</a></span></li><li><span><a href="#Análisis-de-resultados" data-toc-modified-id="Análisis-de-resultados-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Análisis de resultados</a></span></li><li><span><a href="#Categorias-de-analisis-del-modelo" data-toc-modified-id="Categorias-de-analisis-del-modelo-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Categorias de analisis del modelo</a></span></li></ul></li><li><span><a href="#Unidades-de-activación" data-toc-modified-id="Unidades-de-activación-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Unidades de activación</a></span><ul class="toc-item"><li><span><a href="#Sigmoid" data-toc-modified-id="Sigmoid-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Sigmoid</a></span><ul class="toc-item"><li><span><a href="#Instanciando-el-modelo" data-toc-modified-id="Instanciando-el-modelo-3.1.1"><span class="toc-item-num">3.1.1&nbsp;&nbsp;</span>Instanciando el modelo</a></span></li><li><span><a href="#Gráficas" data-toc-modified-id="Gráficas-3.1.2"><span class="toc-item-num">3.1.2&nbsp;&nbsp;</span>Gráficas</a></span></li></ul></li><li><span><a href="#ReLU" data-toc-modified-id="ReLU-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>ReLU</a></span><ul class="toc-item"><li><span><a href="#Instanciando-el-modelo" data-toc-modified-id="Instanciando-el-modelo-3.2.1"><span class="toc-item-num">3.2.1&nbsp;&nbsp;</span>Instanciando el modelo</a></span></li><li><span><a href="#Gráficas" data-toc-modified-id="Gráficas-3.2.2"><span class="toc-item-num">3.2.2&nbsp;&nbsp;</span>Gráficas</a></span></li></ul></li><li><span><a href="#Resultados" data-toc-modified-id="Resultados-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Resultados</a></span></li><li><span><a href="#Bonus-Track:-tanh" data-toc-modified-id="Bonus-Track:-tanh-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Bonus Track: tanh</a></span><ul class="toc-item"><li><span><a href="#Instanciando-el-modelo" data-toc-modified-id="Instanciando-el-modelo-3.4.1"><span class="toc-item-num">3.4.1&nbsp;&nbsp;</span>Instanciando el modelo</a></span></li><li><span><a href="#Gráficas" data-toc-modified-id="Gráficas-3.4.2"><span class="toc-item-num">3.4.2&nbsp;&nbsp;</span>Gráficas</a></span></li></ul></li><li><span><a href="#Conclusiones" data-toc-modified-id="Conclusiones-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Conclusiones</a></span></li></ul></li><li><span><a href="#Inicialización-de-parámetros" data-toc-modified-id="Inicialización-de-parámetros-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Inicialización de parámetros</a></span><ul class="toc-item"><li><span><a href="#Zeros" data-toc-modified-id="Zeros-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Zeros</a></span><ul class="toc-item"><li><span><a href="#Gráficas-y-conclusiones" data-toc-modified-id="Gráficas-y-conclusiones-4.1.1"><span class="toc-item-num">4.1.1&nbsp;&nbsp;</span>Gráficas y conclusiones</a></span></li></ul></li><li><span><a href="#V.A-Normal" data-toc-modified-id="V.A-Normal-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>V.A Normal</a></span><ul class="toc-item"><li><span><a href="#Gráficas-y-conclusiones" data-toc-modified-id="Gráficas-y-conclusiones-4.2.1"><span class="toc-item-num">4.2.1&nbsp;&nbsp;</span>Gráficas y conclusiones</a></span></li></ul></li><li><span><a href="#Valores-por-defecto-(glorot_uniform)" data-toc-modified-id="Valores-por-defecto-(glorot_uniform)-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Valores por defecto (glorot_uniform)</a></span><ul class="toc-item"><li><span><a href="#Gráficas-y-conclusiones" data-toc-modified-id="Gráficas-y-conclusiones-4.3.1"><span class="toc-item-num">4.3.1&nbsp;&nbsp;</span>Gráficas y conclusiones</a></span></li></ul></li></ul></li><li><span><a href="#Optimizadores" data-toc-modified-id="Optimizadores-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Optimizadores</a></span><ul class="toc-item"><li><span><a href="#SGD" data-toc-modified-id="SGD-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>SGD</a></span></li><li><span><a href="#RMSprop" data-toc-modified-id="RMSprop-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>RMSprop</a></span><ul class="toc-item"><li><span><a href="#Gráficas-y-conclusiones" data-toc-modified-id="Gráficas-y-conclusiones-5.2.1"><span class="toc-item-num">5.2.1&nbsp;&nbsp;</span>Gráficas y conclusiones</a></span></li></ul></li><li><span><a href="#Adam" data-toc-modified-id="Adam-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Adam</a></span><ul class="toc-item"><li><span><a href="#Gráficas-y-conclusiones" data-toc-modified-id="Gráficas-y-conclusiones-5.3.1"><span class="toc-item-num">5.3.1&nbsp;&nbsp;</span>Gráficas y conclusiones</a></span></li></ul></li></ul></li><li><span><a href="#Regularización-y-red-final" data-toc-modified-id="Regularización-y-red-final-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Regularización y red final</a></span><ul class="toc-item"><li><span><a href="#Evaluación-del-modelo-en-datos-de-test" data-toc-modified-id="Evaluación-del-modelo-en-datos-de-test-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Evaluación del modelo en datos de test</a></span><ul class="toc-item"><li><span><a href="#Esquema-del-modelo" data-toc-modified-id="Esquema-del-modelo-6.1.1"><span class="toc-item-num">6.1.1&nbsp;&nbsp;</span>Esquema del modelo</a></span></li><li><span><a href="#Metricas-de-evaluacion" data-toc-modified-id="Metricas-de-evaluacion-6.1.2"><span class="toc-item-num">6.1.2&nbsp;&nbsp;</span>Metricas de evaluacion</a></span></li><li><span><a href="#Matriz-de-confusión" data-toc-modified-id="Matriz-de-confusión-6.1.3"><span class="toc-item-num">6.1.3&nbsp;&nbsp;</span>Matriz de confusión</a></span></li><li><span><a href="#Conclusiones" data-toc-modified-id="Conclusiones-6.1.4"><span class="toc-item-num">6.1.4&nbsp;&nbsp;</span>Conclusiones</a></span></li></ul></li></ul></li></ul></div>

# %% [markdown]
# # Trabajo 2: Aspectos prácticos de las redes neuronales
#
# En este segundo trabajo, vamos a continuar desarrollando el problema de Fashion MNIST, con el objetivo de entender los aspectos prácticos del entrenamiento de redes neuronales que hemos visto en el Tema 4.
#
# El código utilizado para contestar tiene que quedar claramente reflejado en el Notebook. Puedes crear nuevas cells si así lo deseas para estructurar tu código y sus salidas. A la hora de entregar el notebook, **asegúrate de que los resultados de ejecutar tu código han quedado guardados**.

# %%
# Puedes añadir todos los imports adicionales que necesites aquí
import keras
from keras.datasets import fashion_mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout, InputLayer
from keras.layers.normalization import BatchNormalization
from keras.callbacks import ReduceLROnPlateau, EarlyStopping

import tensorflow as tf

import matplotlib
import matplotlib.pyplot as plt

from sklearn.metrics import confusion_matrix
import numpy as np
import itertools

# %% [markdown]
# ## Obtención de los datos y pre-processing

# %%
(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()
x_train = x_train / 255.0
x_test = x_test / 255.0

# %% [markdown]
# ## Consideraciones iniciales

# %% [markdown]
# ### Train-validation-test split
#
# En todos los modelos que entrenemos, vamos a partir los datos de training (x_train) en dos sets: training y validación. De este modo, al final tendremos tres datasets distintos: training, validation, y test. Esta es una estrategia común en el aprendizaje automático, en la que los datos de test (o held-out data) se
# "esconden" hasta el final. Los datos de validación se utilizan para estimar cómo de bien están funcionando nuestros modelos y para observar si estamos cayendo en overfitting. Esto nos permite cambiar hiperparámetros y probar distintas arquitecturas **sabiendo que no estamos utilizando información del test set para "optimizar" los resultados en éste** (si eligiéramos nuestro mejor modelo en base a los resultados de test, estaríamos "haciendo trampas", ya que se ha utilizado la información contenida en éste para elegir el modelo y las métricas reportadas serían optimistas).
#
# Para utilizar un split training-validation data durante el entrenamiento, podemos partir nosotros mismos los datos o dejar que Keras lo haga. Podéis ver cómo hacer estas particiones en la documentación de *fit*.
#
# #### **Requisito: En todos los entrenamientos de esta práctica, se requiere utilizar el 20% de los datos en x_train como  conjunto de datos de validación **

# %%
num_classes = 10

#Conjuntos de entrada
x_val = x_train[48000:]
x_train = x_train[:48000]

#Clasificaciones
y_val = y_train[48000:]
y_train = y_train[:48000]

x_train = x_train.reshape(48000, 784)
x_val = x_val.reshape(12000, 784)
x_test = x_test.reshape(10000, 784)

x_train = x_train.astype("float32")
x_val = x_val.astype("float32")
x_test = x_test.astype("float32")

#Lo convertimos en un vector one-hot
y_train = keras.utils.to_categorical(y_train, num_classes)
y_val = keras.utils.to_categorical(y_val, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# %% [markdown]
# ### Un error común con modelos de Keras
#
# En esta práctica entrenaremos varios modelos para comparar resultados. Un error común en Keras es no instanciar un nuevo modelo cada vez que hacemos un nuevo entrenamiento. Al hacer
#
# *model = Sequential()*
#
# *model.add(lo que sea)  # Definición del modelo*
#
# *model.fit()*
#
# si queremos entrenar un nuevo modelo o el mismo modelo otra vez, es necesario volver a inicializar el modelo con model = Sequential(). Si olvidamos este paso y volvemos a hacer fit(), el modelo seguirá entrenando por donde se quedó en el último fit().

# %% [markdown]
# ### Análisis de resultados
#
# A la hora de escribir las respuestas y los análisis pedidos, es importante presentar las conclusiones de manera adecuada a partir de lo visto en nuestros experimentos. Los Jupyter Notebook son una herramienta imprescindible para *data scientists* e ingenieros de Machine Learning para presentar los resultados, incluyendo soporte para incluir gráficas y elementos visuales. Podéis explicar vuestras observaciones del modo que consideréis adecuado, si bien recomendamos la utilización de gráficas para evaluar los entrenamientos y comparar resultados.
#
# Como ayuda, las siguientes funciones pueden resultar interesantes a la hora de evaluar resultados. Todas ellas utilizan el objeto *history* que podéis obtener como salida del método *fit()* de Keras:
#
# history = model.fit(x_train, y_train, ...)
#
# Por supuesto, podéis modificarlas y utilizarlas como prefiráis para crear vuestros propios informes.

# %%
def plot_acc(history, title="Model Accuracy"):
    """Imprime una gráfica mostrando la accuracy por epoch obtenida en un entrenamiento"""
    plt.plot(history.history['acc'])
    plt.plot(history.history['val_acc'])
    plt.title(title)
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Val'], loc='upper left')
    plt.show()
    
def plot_loss(history, title="Model Loss"):
    """Imprime una gráfica mostrando la pérdida por epoch obtenida en un entrenamiento"""
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title(title)
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Val'], loc='upper right')
    plt.show()
    
def plot_compare_losses(history1, history2, history3, bonus, name1="Red 1",
                        name2="Red 2", name3="Red 3", title="Graph title"):
    """Compara losses de dos entrenamientos con nombres name1 y name2"""
    plt.plot(history1.history['loss'], color="green")
    plt.plot(history1.history['val_loss'], 'r--', color="green")
    plt.plot(history2.history['loss'], color="blue")
    plt.plot(history2.history['val_loss'], 'r--', color="blue")
    if bonus == 1:
        plt.plot(history3.history['loss'], color="red")
        plt.plot(history3.history['val_loss'], 'r--', color="red")
    plt.title(title)
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    if bonus == 1:
        plt.legend(['Train ' + name1, 'Val ' + name1, 
                    'Train ' + name2, 'Val ' + name2,
                    'Train ' + name3, 'Val ' + name3],
                   loc='upper right')
    else:
         plt.legend(['Train ' + name1, 'Val ' + name1, 
                     'Train ' + name2, 'Val ' + name2], 
               loc='lower right')
    plt.show()
    
def plot_compare_accs(history1, history2, history3, bonus, name1="Red 1",
                      name2="Red 2", name3="Red 3", title="Graph title"):
    """Compara accuracies de dos entrenamientos con nombres name1 y name2"""
    plt.plot(history1.history['acc'], color="green")
    plt.plot(history1.history['val_acc'], 'r--', color="green")
    plt.plot(history2.history['acc'], color="blue")
    plt.plot(history2.history['val_acc'], 'r--', color="blue")
    if bonus == 1:
        plt.plot(history3.history['acc'], color="red")
        plt.plot(history3.history['val_acc'], 'r--', color="red")
    plt.title(title)
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    if bonus == 1:
        plt.legend(['Train ' + name1, 'Val ' + name1, 
                    'Train ' + name2, 'Val ' + name2,
                    'Train ' + name3, 'Val ' + name3],
                   loc='upper right')
    else:
         plt.legend(['Train ' + name1, 'Val ' + name1, 
                     'Train ' + name2, 'Val ' + name2], 
               loc='lower right')
    plt.show()
    
# Nota: podéis cambiar los números aquí presentes y ejecutar esta línea si queréis cambiar el tamaño
# de las gráficas
matplotlib.rcParams['figure.figsize'] = [15, 10]

def plot_confusion_matrix(cm, classes, normalize=False, title='Confusion matrix', cmap=plt.cm.Greens):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %% [markdown]
# ### Categorias de analisis del modelo

# %% [markdown]
# Se pueden definir varias categorias en función de las gráficas:
#
# Underfitting – Validation and training error altos.
#
# Overfitting – Validation error alto, training error bajo.
#
# Buen ajuste – Validation error bajo, ligeramente superior que el training error.
#
# Ajuste indefinido - Validation error bajo, training error "alto"

# %% [markdown]
# ## Unidades de activación

# %% [markdown]
# En este ejercicio, vamos a evaluar la importancia de utilizar las unidades de activación adecuadas. Como hemos visto en clase, funciones de activación como sigmoid han dejado de utilizarse en favor de otras unidades como ReLU.
#
# **Ejercicio 1**: Partiendo de una red sencilla como la desarrollada en el Trabajo 1, escribir un breve análisis comparando la utilización de unidades sigmoid y ReLU (por ejemplo, se pueden comentar aspectos como velocidad de convergencia, métricas obtenidas...). Explicar por qué pueden darse estas diferencias. Opcionalmente, comparar con otras activaciones disponibles en Keras.
#
# *Pista: Usando redes más grandes se hace más sencillo apreciar las diferencias. Es mejor utilizar al menos 3 o 4 capas densas.*

# %% [markdown]
# ### Sigmoid

# %% [markdown]
# #### Instanciando el modelo

# %%
batch_size = 256
epochs = 1000

# %%
## Tu código y comentarios de texto aquí
model = Sequential()
model.add(Dense(64, activation="sigmoid", input_shape=(784,)))
model.add(Dropout(0.2))
model.add(Dense(32, activation="sigmoid"))
model.add(Dropout(0.2))
model.add(Dense(16, activation="sigmoid"))
model.add(Dropout(0.2))
model.add(Dense(num_classes, activation="softmax"))

model.summary()
## Puedes incluir tantas celdas como quieras
## No olvides utilizar celdas de Markdown para texto
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_5 (Dense)              (None, 64)                50240
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_6 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_7 (Dense)              (None, 16)                528
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 16)                0
# _________________________________________________________________
# dense_8 (Dense)              (None, 10)                170
# ...
# Total params: 53,018
# ...

# %%
from keras.optimizers import sgd

model.compile(loss = 'categorical_crossentropy', 
              optimizer = sgd(),
              metrics = ['accuracy']
             )

# %%
history1 = model.fit(x_train, y_train,
                   batch_size=batch_size,
                   epochs=epochs,
                   verbose=1,
                   validation_data=(x_val, y_val))
# Out:
# Train on 48000 samples, validate on 12000 samples
# Epoch 1/1000
# 48000/48000 [==============================] - 0s 9us/step - loss: 2.3966 - acc: 0.0994 - val_loss: 2.3204 - val_acc: 0.0983
# Epoch 2/1000
# 48000/48000 [==============================] - 0s 6us/step - loss: 2.3397 - acc: 0.1006 - val_loss: 2.3026 - val_acc: 0.0983
# Epoch 3/1000
# 48000/48000 [==============================] - 0s 6us/step - loss: 2.3285 - acc: 0.1017 - val_loss: 2.2989 - val_acc: 0.1003
# Epoch 4/1000
# 48000/48000 [==============================] - 0s 6us/step - loss: 2.3258 - acc: 0.1032 - val_loss: 2.2970 - val_acc: 0.1435
# Epoch 5/1000
# 48000/48000 [==============================] - 0s 6us/step - loss: 2.3237 - acc: 0.1068 - val_loss: 2.2955 - val_acc: 0.1678
# Epoch 6/1000
# 48000/48000 [==============================] - 0s 6us/step - loss: 2.3176 - acc: 0.1071 - val_loss: 2.2940 - val_acc: 0.2655
# Epoch 7/1000
# ...

# %% [markdown]
# #### Gráficas

# %%
plot_acc(history1, title="Model Accuracy")
plot_loss(history1, title="Model Loss")

# %% [markdown]
# ### ReLU

# %% [markdown]
# #### Instanciando el modelo

# %%
## Tu código y comentarios de texto aquí
model2 = Sequential()
model2.add(Dense(64, activation="relu", input_shape=(784,)))
model2.add(Dropout(0.2))
model2.add(Dense(32, activation="relu"))
model2.add(Dropout(0.2))
model2.add(Dense(16, activation="relu"))
model2.add(Dropout(0.2))
model2.add(Dense(num_classes, activation="softmax"))

model2.summary()
## Puedes incluir tantas celdas como quieras
## No olvides utilizar celdas de Markdown para texto
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_9 (Dense)              (None, 64)                50240
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_10 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_11 (Dense)             (None, 16)                528
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 16)                0
# _________________________________________________________________
# dense_12 (Dense)             (None, 10)                170
# ...
# Total params: 53,018
# ...

# %%
model2.compile(loss = 'categorical_crossentropy', 
              optimizer = sgd(),
              metrics = ['accuracy']
             )

# %%
history2 = model2.fit(x_train, y_train,
                   batch_size=batch_size,
                   epochs=epochs,
                   verbose=1,
                   validation_data=(x_val, y_val))
# Out:
# Train on 48000 samples, validate on 12000 samples
# Epoch 1/1000
# 48000/48000 [==============================] - 0s 9us/step - loss: 2.0828 - acc: 0.2649 - val_loss: 1.6812 - val_acc: 0.5219
# Epoch 2/1000
# 48000/48000 [==============================] - 0s 6us/step - loss: 1.6616 - acc: 0.4150 - val_loss: 1.2213 - val_acc: 0.6412
# Epoch 3/1000
# 48000/48000 [==============================] - 0s 6us/step - loss: 1.4040 - acc: 0.4898 - val_loss: 1.0234 - val_acc: 0.6662
# Epoch 4/1000
# 48000/48000 [==============================] - 0s 6us/step - loss: 1.2669 - acc: 0.5335 - val_loss: 0.9140 - val_acc: 0.6859
# Epoch 5/1000
# 48000/48000 [==============================] - 0s 6us/step - loss: 1.1723 - acc: 0.5653 - val_loss: 0.8428 - val_acc: 0.7080
# Epoch 6/1000
# 48000/48000 [==============================] - 0s 6us/step - loss: 1.0970 - acc: 0.5907 - val_loss: 0.7939 - val_acc: 0.7118
# Epoch 7/1000
# ...

# %% [markdown]
# #### Gráficas

# %%
plot_acc(history2, title="Model Accuracy")
plot_loss(history2, title="Model Loss")

# %% [markdown]
# ### Resultados

# %%
plot_compare_losses(history1, history2, history2, 0,  name1="Sigmoid activation",
                        name2="ReLU activation", title="Loss Comparsion")

plot_compare_accs(history1, history2, history2, 0, name1="Sigmoid activation",
                        name2="ReLU activation", title="Accuracy Comparsion")

# %% [markdown]
# ### Bonus Track: tanh

# %% [markdown]
# #### Instanciando el modelo

# %%
## Tu código y comentarios de texto aquí
model3 = Sequential()
model3.add(Dense(64, activation="tanh", input_shape=(784,)))
model3.add(Dropout(0.2))
model3.add(Dense(32, activation="tanh"))
model3.add(Dropout(0.2))
model3.add(Dense(16, activation="tanh"))
model3.add(Dropout(0.2))
model3.add(Dense(num_classes, activation="softmax"))

model3.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_13 (Dense)             (None, 64)                50240
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_14 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 32)                0
# _________________________________________________________________
# dense_15 (Dense)             (None, 16)                528
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 16)                0
# _________________________________________________________________
# dense_16 (Dense)             (None, 10)                170
# ...
# Total params: 53,018
# ...

# %%
model3.compile(loss = 'categorical_crossentropy', 
              optimizer = sgd(),
              metrics = ['accuracy']
             )

# %%
batch_size = 256
epochs = 1000
num_classes = 10

history3 = model3.fit(x_train, y_train,
                   batch_size=batch_size,
                   epochs=epochs,
                   verbose=1,
                   validation_data=(x_val, y_val))
# Out:
# Train on 48000 samples, validate on 12000 samples
# Epoch 1/1000
# 48000/48000 [==============================] - 0s 10us/step - loss: 1.7563 - acc: 0.4074 - val_loss: 1.3215 - val_acc: 0.6264
# Epoch 2/1000
# 48000/48000 [==============================] - 0s 6us/step - loss: 1.3070 - acc: 0.5840 - val_loss: 1.0646 - val_acc: 0.6893
# Epoch 3/1000
# 48000/48000 [==============================] - 0s 6us/step - loss: 1.1232 - acc: 0.6420 - val_loss: 0.9279 - val_acc: 0.7156
# Epoch 4/1000
# 48000/48000 [==============================] - 0s 6us/step - loss: 1.0132 - acc: 0.6701 - val_loss: 0.8406 - val_acc: 0.7303
# Epoch 5/1000
# 48000/48000 [==============================] - 0s 6us/step - loss: 0.9379 - acc: 0.6918 - val_loss: 0.7790 - val_acc: 0.7488
# Epoch 6/1000
# 48000/48000 [==============================] - 0s 6us/step - loss: 0.8840 - acc: 0.7071 - val_loss: 0.7320 - val_acc: 0.7588
# Epoch 7/1000
# ...

# %% [markdown]
# #### Gráficas

# %%
plot_acc(history3, title="Model Accuracy")
plot_loss(history3, title="Model Loss")

# %%
plot_compare_losses(history1, history2, history3, 1,  name1="Sigmoid activation",
                        name2="ReLU activation", name3="tanh activation", title="Loss Comparsion")

plot_compare_accs(history1, history2, history3, 1, name1="Sigmoid activation",
                        name2="ReLU activation", name3="tanh activation", title="Accuracy Comparsion")

# %% [markdown]
# ### Conclusiones

# %% [markdown]
# Tenemos un gran surtido de unidades de activación para elegir. A la vista de los resultados y como se recomienda en la actualidad, la unidad ReLU es la que mejores resultados ha presentado.
#
# Si esto es un problema se puede probar alguna variante de Leaky ReLU o Maxout. En general, debería evitarse el uso de sigmoid por la gran cantidad de problemas que presenta.

# %% [markdown]
# ## Inicialización de parámetros

# %% [markdown]
# En este ejercicio, vamos a evaluar la importancia de una correcta inicialización de parámetros en una red neuronal.
#
# **Ejercicio 2**: Partiendo de una red similar a la del ejercicio anterior (usando ya ReLUs), comentar las diferencias que se aprecian en el entrenamiento al utilizar distintas estrategias de inicialización de parámetros. Para ello, inicializar todas las capas con las siguientes estrategias, disponibles en Keras, y analizar sus diferencias:
#
# * Inicialización con ceros.
# * Inicialización con una variable aleatoria normal.
# * Inicialización con los valores por defecto de Keras para una capa Dense (estrategia *glorot uniform*)

# %% [markdown]
# ### Zeros

# %%
# A la vista de las gráficas de ReLU, bajamos los epochs a 250,
# que es donde se obtienen resultados aceptables (no mejoran mucho más) de acc/loss
batch_size = 256
epochs = 250
num_classes = 10

# %%
## Tu código y comentarios de texto aquí
model = Sequential()
model.add(Dense(64, 
                activation="relu", 
                kernel_initializer="zeros", # O keras.initializers.Zeros()
                input_shape=(784,)))
model.add(Dropout(0.2))
model.add(Dense(32, 
                activation="relu",
                kernel_initializer="zeros",))
model.add(Dropout(0.2))
model.add(Dense(16, 
                activation="relu",
                kernel_initializer="zeros",))
model.add(Dropout(0.2))
model.add(Dense(num_classes, activation="softmax"))

model.summary()
## Puedes incluir tantas celdas como quieras
## No olvides utilizar celdas de Markdown para texto
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_29 (Dense)             (None, 64)                50240
# _________________________________________________________________
# dropout_22 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_30 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dropout_23 (Dropout)         (None, 32)                0
# _________________________________________________________________
# dense_31 (Dense)             (None, 16)                528
# _________________________________________________________________
# dropout_24 (Dropout)         (None, 16)                0
# _________________________________________________________________
# dense_32 (Dense)             (None, 10)                170
# ...
# Total params: 53,018
# ...

# %%
model.compile(loss = 'categorical_crossentropy', 
              optimizer = sgd(),
              metrics = ['accuracy']
             )

# %%
history = model.fit(x_train, y_train,
                   batch_size=batch_size,
                   epochs=epochs,
                   verbose=1,
                   validation_data=(x_val, y_val))
# Out:
# Train on 48000 samples, validate on 12000 samples
# Epoch 1/250
# 48000/48000 [==============================] - 1s 11us/step - loss: 2.3026 - acc: 0.0982 - val_loss: 2.3026 - val_acc: 0.0957
# Epoch 2/250
# 48000/48000 [==============================] - 0s 6us/step - loss: 2.3026 - acc: 0.0990 - val_loss: 2.3026 - val_acc: 0.0957
# Epoch 3/250
# 48000/48000 [==============================] - 0s 6us/step - loss: 2.3026 - acc: 0.1005 - val_loss: 2.3026 - val_acc: 0.0957
# Epoch 4/250
# 48000/48000 [==============================] - 0s 6us/step - loss: 2.3026 - acc: 0.1011 - val_loss: 2.3026 - val_acc: 0.0957
# Epoch 5/250
# 48000/48000 [==============================] - 0s 6us/step - loss: 2.3026 - acc: 0.1011 - val_loss: 2.3027 - val_acc: 0.0957
# Epoch 6/250
# 48000/48000 [==============================] - 0s 6us/step - loss: 2.3026 - acc: 0.1011 - val_loss: 2.3027 - val_acc: 0.0957
# Epoch 7/250
# ...

# %% [markdown]
# #### Gráficas y conclusiones

# %%
plot_acc(history, title="Model Accuracy")
plot_loss(history, title="Model Loss")

# %% [markdown]
# Como todas las neuronas de la red tienen la misma salida, todas ellas tendrán el mismo gradiente durante la backpropagation y, por tanto, cambiarán los parámetros de igual manera (De ahí el comportamiento errático de los valores de acc/loss). Es necesaria cierta asimetría en los valores de inicialización para evitar este fenómeno.

# %% [markdown]
# ### V.A Normal

# %%
## Tu código y comentarios de texto aquí
model = Sequential()

model.add(Dense(64, 
                activation="relu", 
                kernel_initializer=keras.initializers.RandomNormal(mean=0.0, stddev=0.05, seed=12345),
                input_shape=(784,)))
model.add(Dropout(0.2))
model.add(Dense(32, 
                activation="relu",
                kernel_initializer=keras.initializers.RandomNormal(mean=0.0, stddev=0.05, seed=12345),))
model.add(Dropout(0.2))
model.add(Dense(16, 
                activation="relu",
                kernel_initializer=keras.initializers.RandomNormal(mean=0.0, stddev=0.05, seed=12345),))
model.add(Dropout(0.2))
model.add(Dense(num_classes, activation="softmax"))

model.summary()
## Puedes incluir tantas celdas como quieras
## No olvides utilizar celdas de Markdown para texto
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_33 (Dense)             (None, 64)                50240
# _________________________________________________________________
# dropout_25 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_34 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dropout_26 (Dropout)         (None, 32)                0
# _________________________________________________________________
# dense_35 (Dense)             (None, 16)                528
# _________________________________________________________________
# dropout_27 (Dropout)         (None, 16)                0
# _________________________________________________________________
# dense_36 (Dense)             (None, 10)                170
# ...
# Total params: 53,018
# ...

# %%
model.compile(loss = 'categorical_crossentropy', 
              optimizer = sgd(),
              metrics = ['accuracy']
             )

# %%
history = model.fit(x_train, y_train,
                   batch_size=batch_size,
                   epochs=epochs,
                   verbose=1,
                   validation_data=(x_val, y_val))
# Out:
# Train on 48000 samples, validate on 12000 samples
# Epoch 1/250
# 48000/48000 [==============================] - 1s 11us/step - loss: 2.2944 - acc: 0.1243 - val_loss: 2.2782 - val_acc: 0.1741
# Epoch 2/250
# 48000/48000 [==============================] - 0s 6us/step - loss: 2.2611 - acc: 0.1961 - val_loss: 2.2189 - val_acc: 0.2904
# Epoch 3/250
# 48000/48000 [==============================] - 0s 6us/step - loss: 2.1781 - acc: 0.2506 - val_loss: 2.0775 - val_acc: 0.3467
# Epoch 4/250
# 48000/48000 [==============================] - 0s 6us/step - loss: 2.0217 - acc: 0.2902 - val_loss: 1.8223 - val_acc: 0.4296
# Epoch 5/250
# 48000/48000 [==============================] - 0s 6us/step - loss: 1.7929 - acc: 0.3445 - val_loss: 1.5109 - val_acc: 0.4912
# Epoch 6/250
# 48000/48000 [==============================] - 0s 6us/step - loss: 1.5865 - acc: 0.4007 - val_loss: 1.2887 - val_acc: 0.5920
# Epoch 7/250
# ...

# %% [markdown]
# #### Gráficas y conclusiones

# %%
plot_acc(history, title="Model Accuracy")
plot_loss(history, title="Model Loss")

# %% [markdown]
# Mucho mejor que la activación por ceros. Al incluir asimetría en los valores de inicialización para evitar el comportamiento errático, se consigue que la red vaya siendo más precisa ya que hay distinto gradiente y los parámetros cambian de distinta manera.

# %% [markdown]
# ### Valores por defecto (glorot_uniform)

# %%
## Tu código y comentarios de texto aquí
model = Sequential()

model.add(Dense(64, 
                activation="relu", 
                kernel_initializer=keras.initializers.glorot_uniform(seed=12345),
                input_shape=(784,)))
model.add(Dropout(0.2))
model.add(Dense(32, 
                activation="relu",
                kernel_initializer=keras.initializers.glorot_uniform(seed=12345)))
model.add(Dropout(0.2))
model.add(Dense(16, 
                activation="relu",
                kernel_initializer=keras.initializers.glorot_uniform(seed=12345)))
model.add(Dropout(0.2))
model.add(Dense(num_classes, activation="softmax"))

model.summary()
## Puedes incluir tantas celdas como quieras
## No olvides utilizar celdas de Markdown para texto
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_37 (Dense)             (None, 64)                50240
# _________________________________________________________________
# dropout_28 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_38 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dropout_29 (Dropout)         (None, 32)                0
# _________________________________________________________________
# dense_39 (Dense)             (None, 16)                528
# _________________________________________________________________
# dropout_30 (Dropout)         (None, 16)                0
# _________________________________________________________________
# dense_40 (Dense)             (None, 10)                170
# ...
# Total params: 53,018
# ...

# %%
model.compile(loss = 'categorical_crossentropy', 
              optimizer = sgd(),
              metrics = ['accuracy']
             )

# %%
history = model.fit(x_train, y_train,
                   batch_size=batch_size,
                   epochs=epochs,
                   verbose=1,
                   validation_data=(x_val, y_val))
# Out:
# Train on 48000 samples, validate on 12000 samples
# Epoch 1/250
# 48000/48000 [==============================] - 1s 13us/step - loss: 2.1701 - acc: 0.1921 - val_loss: 1.9097 - val_acc: 0.2975
# Epoch 2/250
# 48000/48000 [==============================] - 0s 7us/step - loss: 1.8500 - acc: 0.2808 - val_loss: 1.5443 - val_acc: 0.4783
# Epoch 3/250
# 48000/48000 [==============================] - 0s 7us/step - loss: 1.6415 - acc: 0.3424 - val_loss: 1.3411 - val_acc: 0.5430
# Epoch 4/250
# 48000/48000 [==============================] - 0s 7us/step - loss: 1.5155 - acc: 0.4013 - val_loss: 1.2139 - val_acc: 0.6448
# Epoch 5/250
# 48000/48000 [==============================] - 0s 7us/step - loss: 1.4279 - acc: 0.4540 - val_loss: 1.1094 - val_acc: 0.6654
# Epoch 6/250
# 48000/48000 [==============================] - 0s 7us/step - loss: 1.3431 - acc: 0.4874 - val_loss: 1.0202 - val_acc: 0.6677
# Epoch 7/250
# ...

# %% [markdown]
# #### Gráficas y conclusiones

# %%
plot_acc(history, title="Model Accuracy")
plot_loss(history, title="Model Loss")

# %% [markdown]
# En términos generales, reusultados muy similares a los presentados por la V.A Normal. Se ha mejorado los valores de acc/loss y las gráficas se muestran más continuas.

# %% [markdown]
# ##  Optimizadores

# %% [markdown]
# **Ejercicio 3**: Partiendo de una red similar a la del ejercicio anterior (utilizando la mejor estrategia de inicialización observada), comparar y analizar las diferencias que se observan  al entrenar con varios de los optimizadores vistos en clase, incluyendo SGD como optimizador básico (se puede explorar el espacio de hiperparámetros de cada optimizador, aunque para optimizadores más avanzados del estilo de adam y RMSprop es buena idea dejar los valores por defecto provistos por Keras).

# %% [markdown]
# ### SGD

# %% [markdown]
# Ver resultados en el punto 3.3 ya que se utilizó un optimizador SGD con glorot_uniform.

# %% [markdown]
# ### RMSprop

# %%
## Tu código y comentarios de texto aquí
model = Sequential()

model.add(Dense(64, 
                activation="relu", 
                kernel_initializer=keras.initializers.glorot_uniform(seed=12345),
                input_shape=(784,)))
model.add(Dropout(0.2))
model.add(Dense(32, 
                activation="relu",
                kernel_initializer=keras.initializers.glorot_uniform(seed=12345)))
model.add(Dropout(0.2))
model.add(Dense(16, 
                activation="relu",
                kernel_initializer=keras.initializers.glorot_uniform(seed=12345)))
model.add(Dropout(0.2))
model.add(Dense(num_classes, activation="softmax"))

model.summary()
## Puedes incluir tantas celdas como quieras
## No olvides utilizar celdas de Markdown para texto
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_41 (Dense)             (None, 64)                50240
# _________________________________________________________________
# dropout_31 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_42 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dropout_32 (Dropout)         (None, 32)                0
# _________________________________________________________________
# dense_43 (Dense)             (None, 16)                528
# _________________________________________________________________
# dropout_33 (Dropout)         (None, 16)                0
# _________________________________________________________________
# dense_44 (Dense)             (None, 10)                170
# ...
# Total params: 53,018
# ...

# %%
model.compile(loss = 'categorical_crossentropy', 
              optimizer = keras.optimizers.RMSprop(lr=0.001, rho=0.9, epsilon=None, decay=0.0),
              metrics = ['accuracy']
             )

# %%
history = model.fit(x_train, y_train,
                   batch_size=batch_size,
                   epochs=epochs,
                   verbose=1,
                   validation_data=(x_val, y_val))
# Out:
# Train on 48000 samples, validate on 12000 samples
# Epoch 1/250
# 48000/48000 [==============================] - 1s 13us/step - loss: 1.2560 - acc: 0.5402 - val_loss: 0.6732 - val_acc: 0.7860
# Epoch 2/250
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.7996 - acc: 0.7139 - val_loss: 0.5349 - val_acc: 0.8166
# Epoch 3/250
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.6642 - acc: 0.7668 - val_loss: 0.4775 - val_acc: 0.8360
# Epoch 4/250
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.5990 - acc: 0.7906 - val_loss: 0.4551 - val_acc: 0.8435
# Epoch 5/250
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.5574 - acc: 0.8073 - val_loss: 0.4269 - val_acc: 0.8469
# Epoch 6/250
# 48000/48000 [==============================] - 0s 8us/step - loss: 0.5371 - acc: 0.8157 - val_loss: 0.4195 - val_acc: 0.8517
# Epoch 7/250
# ...

# %% [markdown]
# #### Gráficas y conclusiones

# %%
plot_acc(history, title="Model Accuracy")
plot_loss(history, title="Model Loss")

# %% [markdown]
# El optimizador necesita muy pocas epochs (menos de 50) para obtener valores de precision de 0,85, aunque deja de crecer también muy rápido y tiene un comportamiento muy erratico (habría que tunear el learning rate)

# %% [markdown]
# ### Adam

# %%
## Tu código y comentarios de texto aquí
model = Sequential()

model.add(Dense(64, 
                activation="relu", 
                kernel_initializer=keras.initializers.glorot_uniform(seed=12345),
                input_shape=(784,)))
model.add(Dropout(0.2))
model.add(Dense(32, 
                activation="relu",
                kernel_initializer=keras.initializers.glorot_uniform(seed=12345),))
model.add(Dropout(0.2))
model.add(Dense(16, 
                activation="relu",
                kernel_initializer=keras.initializers.glorot_uniform(seed=12345),))
model.add(Dropout(0.2))
model.add(Dense(num_classes, activation="softmax"))

model.summary()
## Puedes incluir tantas celdas como quieras
## No olvides utilizar celdas de Markdown para texto
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_45 (Dense)             (None, 64)                50240
# _________________________________________________________________
# dropout_34 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_46 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dropout_35 (Dropout)         (None, 32)                0
# _________________________________________________________________
# dense_47 (Dense)             (None, 16)                528
# _________________________________________________________________
# dropout_36 (Dropout)         (None, 16)                0
# _________________________________________________________________
# dense_48 (Dense)             (None, 10)                170
# ...
# Total params: 53,018
# ...

# %%
model.compile(loss = 'categorical_crossentropy', 
              optimizer = keras.optimizers.Adam(lr=0.001, 
                                                beta_1=0.9, 
                                                beta_2=0.999, 
                                                epsilon=None, 
                                                decay=0.0, 
                                                amsgrad=False),
              metrics = ['accuracy']
             )

# %%
history = model.fit(x_train, y_train,
                   batch_size=batch_size,
                   epochs=epochs,
                   verbose=1,
                   validation_data=(x_val, y_val))
# Out:
# Train on 48000 samples, validate on 12000 samples
# Epoch 1/250
# 48000/48000 [==============================] - 1s 14us/step - loss: 1.3503 - acc: 0.5036 - val_loss: 0.6648 - val_acc: 0.7916
# Epoch 2/250
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.8041 - acc: 0.7091 - val_loss: 0.5145 - val_acc: 0.8243
# Epoch 3/250
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.6687 - acc: 0.7650 - val_loss: 0.4667 - val_acc: 0.8419
# Epoch 4/250
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.6022 - acc: 0.7932 - val_loss: 0.4503 - val_acc: 0.8433
# Epoch 5/250
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.5647 - acc: 0.8085 - val_loss: 0.4266 - val_acc: 0.8506
# Epoch 6/250
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.5374 - acc: 0.8173 - val_loss: 0.4171 - val_acc: 0.8524
# Epoch 7/250
# ...

# %% [markdown]
# #### Gráficas y conclusiones

# %%
plot_acc(history, title="Model Accuracy")
plot_loss(history, title="Model Loss")

# %% [markdown]
# Comportamiento similar al RMSprop, pero con valores más estables (El learning rate es más pequeño) y un poco más resistente al overfitting.

# %% [markdown]
# ## Regularización y red final

# %% [markdown]
# **Ejercicio 4.1**: Entrenar una red final que sea capaz de obtener una accuracy en el validation set cercana al 90%. Para ello, combinar todo lo aprendido anteriormente y utilizar técnicas de regularización para evitar overfitting. Algunos de los elementos que pueden tenerse en cuenta son los siguientes.
#
# * Número de capas y neuronas por capa
# * Optimizadores y sus parámetros
# * Batch size
# * Unidades de activación
# * Uso de capas dropout, regularización L2, regularización L1...
# * Early stopping (se puede aplicar como un callback de Keras, o se puede ver un poco "a ojo" cuándo el modelo empieza a caer en overfitting y seleccionar el número de epochs necesarias)
# * Batch normalization
#
# Si los modelos entrenados anteriormente ya se acercaban al valor requerido de accuracy, probar distintas estrategias igualmente y comentar los resultados.
#
# Explicar brevemente la estrategia seguida y los modelos probados para obtener el modelo final, que debe verse entrenado en este Notebook. No es necesario guardar el entrenamiento de todos los modelos que se han probado, es suficiente con explicar cómo se ha llegado al modelo final.

# %%
batch_size = 500
epochs = 250
num_classes = 10

# %%
## Tu código y comentarios de texto aquí
model = Sequential()

# First Layer
model.add(InputLayer(input_shape=(784,)))
# Normalization
model.add(BatchNormalization())
# Dropout
model.add(Dropout(0.1))
# Fully Connected Layer
model.add(Dense(128, 
                activation='relu',
                kernel_initializer=keras.initializers.glorot_uniform(seed=12345)))
# Dropout
model.add(Dropout(0.1))
# Fully Connected Layer
model.add(Dense(64, 
                activation='relu', 
                kernel_initializer=keras.initializers.glorot_uniform(seed=12345)))
# Normalization
model.add(BatchNormalization())
# Last Layer
model.add(Dense(num_classes, activation='softmax'))

# %%
model.compile(loss = 'categorical_crossentropy', 
              optimizer = keras.optimizers.Adam(lr=0.001, 
                                                beta_1=0.9, 
                                                beta_2=0.999, 
                                                epsilon=None, 
                                                decay=0.0, 
                                                amsgrad=False),
              metrics = ['accuracy']
             )

# %%
#Early Stopping y auto tune del Learning rate.
reduce_lr = ReduceLROnPlateau(monitor='val_acc',
                              factor=0.0001,
                              patience=5, 
                              min_lr=0.00001)

early_stop = EarlyStopping(monitor='val_acc', 
                           min_delta=0, 
                           patience=10,
                           verbose=0, 
                           mode='auto', 
                           baseline=None, 
                           #restore_best_weights=False #Actualizar keras a 2.2.3
                          )

# %%
history = model.fit(x_train, y_train,
                    callbacks=[reduce_lr, early_stop],
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1,
                    validation_data=(x_val, y_val))
# Out:
# Train on 48000 samples, validate on 12000 samples
# Epoch 1/250
# 48000/48000 [==============================] - 4s 79us/step - loss: 0.6751 - acc: 0.7661 - val_loss: 0.4310 - val_acc: 0.8440
# Epoch 2/250
# 48000/48000 [==============================] - 3s 53us/step - loss: 0.4309 - acc: 0.8460 - val_loss: 0.3874 - val_acc: 0.8610
# Epoch 3/250
# 48000/48000 [==============================] - 3s 55us/step - loss: 0.3835 - acc: 0.8621 - val_loss: 0.3545 - val_acc: 0.8720
# Epoch 4/250
# 48000/48000 [==============================] - 3s 53us/step - loss: 0.3534 - acc: 0.8738 - val_loss: 0.3372 - val_acc: 0.8778
# Epoch 5/250
# 48000/48000 [==============================] - 3s 53us/step - loss: 0.3298 - acc: 0.8802 - val_loss: 0.3333 - val_acc: 0.8794
# Epoch 6/250
# 48000/48000 [==============================] - 3s 52us/step - loss: 0.3152 - acc: 0.8863 - val_loss: 0.3212 - val_acc: 0.8792
# Epoch 7/250
# ...

# %%
plot_acc(history, title="Model Accuracy")
plot_loss(history, title="Model Loss")

# %% [markdown]
# **Explicación:** Para esta red, se ha ido siguiendo la estructura del notebook. En vista de los resultados obtenidos en el apartado de "unidades de activacion", "inicializacion de parámetros" y "Optimizadores", es lógico haber escogido los que mejor resultado han dado: Unidad ReLU, Inicializacion por defecto (glorot_uniform) y optimizador Adam.
#
# Dado que durante todo el notebook se ha utilizado un gran número de epochs (Para obtener gráficas de donde se puedan sacar conclusiones), se ha decidido usar el early_stop para reducir el tiempo de entrenamiento.
#
# En cuanto al número de neuronas, se han usado más capas en los ejemplos previos (También para obtener mejores gráficas), pero con unos resultados peores que los del Notebook 1 (2 capas). Es por esto que se ha vuelto a reducir el número de capas a 3, con los valores de neuronas por defecto del notebook 1 (128,64,10).
#
# Se ha usado también BatchNormalization para hacer que la red converja más rápidamente y permitir mayores "learning rate", hacer que los pesos se inicialicen más facilmente y favorecer los resultados en términos generales.
#
# Para jugar con el "Learning Rate" y poder ibtener mejores resultados de precisión, se ha creado un callback que lo va ajustando en función de la precisión sobre los valores de validación (reduce_lr).

# %% [markdown]
# ### Evaluación del modelo en datos de test

# %% [markdown]
# Una vez elegido el que creemos que es nuestro mejor modelo a partir de la estimación que hemos visto en los datos de validación, es hora de utilizar los datos de test para ver cómo se comporta nuestro modelo ante nuevos datos. Si hemos hecho bien las cosas, este número debería ser parecido al valor de nuestra estimación vista en los datos de validación.
#
# **Pregunta 4.2**. Utilizando nuestro mejor modelo, obtener la accuracy resultante en el dataset de test. Comentar este resultado.

# %% [markdown]
# #### Esquema del modelo

# %%
## Tu código y comentarios de texto aquí
from IPython.display import SVG
from keras.utils.vis_utils import model_to_dot

SVG(model_to_dot(model).create(prog='dot', format='svg'))

# %% [markdown]
# #### Metricas de evaluacion

# %%
print(model.metrics_names)
loss, acc = model.evaluate(x_test, 
                           y_test,
                           batch_size=batch_size)
print('Test loss:', loss)
print('Test accuracy:', acc)
# Out:
# ['loss', 'acc']
# 10000/10000 [==============================] - 0s 18us/step
# Test loss: 0.31064402088522913
# Test accuracy: 0.8956000000238419

# %% [markdown]
# #### Matriz de confusión

# %%
#Llamamos a la funcion predict de Keras.
y_pred = model.predict(x_test)

#Creamos la matriz de confusion
matrix = confusion_matrix(y_test.argmax(axis=1), y_pred.argmax(axis=1))

# La pintamos
plot_confusion_matrix(matrix, ["T-shirt/top",
                               "Trouser",
                               "Pullover",
                               "Dress",
                               "Coat",
                               "Sandal",
                               "Shirt",
                               "Sneaker",
                               "Bag",
                               "Ankle boot"])

# %% [markdown]
# #### Conclusiones

# %% [markdown]
# Como el modelo ha sido compilado con "metrics = ['accuracy']", el retorno del método .evaluate() de Keras nos da la precisión del modelo y su error. Estos resultados están muy cercanos a los mostrados por el modelo en el conjunto de validación durante el entrenamiento. Por esta cercanía y como se ha comentado en el apartado 2.4, podemos concluir que se ha realizado un buen ajuste. Para obtener mejores resultados, hay que utilizar técnicas más avanzadas en el procesamiento de imágenes como "data augmentation" y redes convolucionales.
